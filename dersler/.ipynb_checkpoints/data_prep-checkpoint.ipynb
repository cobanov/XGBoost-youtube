# %%
import pandas as pd
import seaborn as sns
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("../datasets/iris.csv")

# %%
# EDA

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.groupby(by="Species").count()
# Out:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa      50             50            50             50            50
# Iris-versicolor  50             50            50             50            50
# Iris-virginica   50             50            50             50            50

# %%
#Visualize

# %%
sns.scatterplot(x="SepalLengthCm", y="SepalWidthCm", hue="Species", data=data)

# %%
sns.pairplot(data, hue="Species")

# %%
corr = data.corr()
sns.heatmap(data=corr, cmap="YlGnBu")

# %%
#Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
data["Species"] = label_encoder.fit_transform(data["Species"])
    
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
data["Species"].value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: Species, dtype: int64

# %%
data.drop("Id", axis=1, inplace=True)

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
X, y = data.iloc[:, :-1], data.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=123)

# %%
dmatrix_train = xgb.DMatrix(data=X_train, label=y_train)
dmatrix_test = xgb.DMatrix(data=X_test, label=y_test)
# Out:
# C:\Users\mertc\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \

# %%
param = {'max_depth':2, 'eta':1, 'objective':'multi:softprob', 'num_class':3}
num_round = 2
model = xgb.train(param, dmatrix_train, num_round)
# make prediction
preds = model.predict(dmatrix_test)

# %%
preds[:10]
# Out:
# array([[0.0440865 , 0.86334395, 0.09256954],
#        [0.03476592, 0.03587032, 0.9293637 ],
#        [0.03476592, 0.03587032, 0.9293637 ],
#        [0.04631293, 0.906944  , 0.04674305],
#        [0.9217261 , 0.04058198, 0.03769191],
#        [0.08490701, 0.25121772, 0.6638753 ],
#        [0.04631293, 0.906944  , 0.04674305],
#        [0.9217261 , 0.04058198, 0.03769191],
#        [0.9217261 , 0.04058198, 0.03769191],
#        [0.04631293, 0.906944  , 0.04674305]], dtype=float32)

# %%
for i in preds[:5]:
    print(np.argmax(i))
# Out:
# 1
# 2
# 2
# 1
# 0

# %%
best_preds = np.asarray([np.argmax(line) for line in preds])

# %%
best_preds
# Out:
# array([1, 2, 2, 1, 0, 2, 1, 0, 0, 1, 2, 0, 1, 2, 2, 2, 0, 0, 1, 0, 0, 1,
#        0, 2, 0, 0, 0, 2, 2, 0, 2, 1, 0, 0, 1, 1, 2, 0, 0, 1, 1, 0, 2, 2,
#        2, 2, 2, 1, 0, 0], dtype=int64)

# %%
import numpy as np
from sklearn.metrics import precision_score, recall_score, accuracy_score

best_preds = np.asarray([np.argmax(line) for line in preds])

print("Precision = {}".format(precision_score(y_test, best_preds, average='macro')))
print("Recall = {}".format(recall_score(y_test, best_preds, average='macro')))
print("Accuracy = {}".format(accuracy_score(y_test, best_preds)))
# Out:
# Precision = 0.9487179487179488
# Recall = 0.9649122807017544
# Accuracy = 0.96

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, best_preds)
# Out:
# array([[20,  0,  0],
#        [ 0, 11,  0],
#        [ 0,  2, 17]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test, best_preds), square=True, annot=True, cbar=False )
